# %%
import nltk

# %%
text = "While it’s easy to get starstruck by its Pro sibling, the OnePlus 9 is a capable alternative at a lower cost. You’re looking at quite a gap, especially in the US where (for some unknown reason), the base 8/128 GB version of the 9 Pro is not available. This means you can have the vanilla phone for $730 or the 12/256 GB Pro for $1,070"
tokens = nltk.word_tokenize(text)
print(tokens)
# Out:
# ['While', 'it', '’', 's', 'easy', 'to', 'get', 'starstruck', 'by', 'its', 'Pro', 'sibling', ',', 'the', 'OnePlus', '9', 'is', 'a', 'capable', 'alternative', 'at', 'a', 'lower', 'cost', '.', 'You', '’', 're', 'looking', 'at', 'quite', 'a', 'gap', ',', 'especially', 'in', 'the', 'US', 'where', '(', 'for', 'some', 'unknown', 'reason', ')', ',', 'the', 'base', '8/128', 'GB', 'version', 'of', 'the', '9', 'Pro', 'is', 'not', 'available', '.', 'This', 'means', 'you', 'can', 'have', 'the', 'vanilla', 'phone', 'for', '$', '730', 'or', 'the', '12/256', 'GB', 'Pro', 'for', '$', '1,070']

# %%
tag = nltk.pos_tag(tokens)
print(tag)
# Out:
# [('While', 'IN'), ('it', 'PRP'), ('’', 'VBZ'), ('s', 'JJ'), ('easy', 'JJ'), ('to', 'TO'), ('get', 'VB'), ('starstruck', 'VBN'), ('by', 'IN'), ('its', 'PRP$'), ('Pro', 'NNP'), ('sibling', 'NN'), (',', ','), ('the', 'DT'), ('OnePlus', 'NNP'), ('9', 'CD'), ('is', 'VBZ'), ('a', 'DT'), ('capable', 'JJ'), ('alternative', 'NN'), ('at', 'IN'), ('a', 'DT'), ('lower', 'JJR'), ('cost', 'NN'), ('.', '.'), ('You', 'PRP'), ('’', 'VBP'), ('re', 'JJ'), ('looking', 'VBG'), ('at', 'IN'), ('quite', 'PDT'), ('a', 'DT'), ('gap', 'NN'), (',', ','), ('especially', 'RB'), ('in', 'IN'), ('the', 'DT'), ('US', 'NNP'), ('where', 'WRB'), ('(', '('), ('for', 'IN'), ('some', 'DT'), ('unknown', 'JJ'), ('reason', 'NN'), (')', ')'), (',', ','), ('the', 'DT'), ('base', 'NN'), ('8/128', 'CD'), ('GB', 'NNP'), ('version', 'NN'), ('of', 'IN'), ('the', 'DT'), ('9', 'CD'), ('Pro', 'NNP'), ('is', 'VBZ'), ('not', 'RB'), ('available', 'JJ'), ('.', '.'), ('This', 'DT'), ('means', 'VBZ'), ('you', 'PRP'), ('can', 'MD'), ('have', 
# ...

# %%
grammar = "NP: {<DT>?<JJ>*<NN>}"
cp  =nltk.RegexpParser(grammar)
result = cp.parse(tag)
print(result)
# Out:
# (S
#   While/IN
#   it/PRP
#   ’/VBZ
#   s/JJ
#   easy/JJ
#   to/TO
#   get/VB
#   starstruck/VBN
#   by/IN
#   its/PRP$
#   Pro/NNP
#   (NP sibling/NN)
#   ,/,
#   the/DT
#   OnePlus/NNP
#   9/CD
#   is/VBZ
#   (NP a/DT capable/JJ alternative/NN)
#   at/IN
#   a/DT
#   lower/JJR
#   (NP cost/NN)
#   ./.
#   You/PRP
#   ’/VBP
#   re/JJ
#   looking/VBG
#   at/IN
#   quite/PDT
#   (NP a/DT gap/NN)
#   ,/,
#   especially/RB
#   in/IN
#   the/DT
#   US/NNP
#   where/WRB
#   (/(
#   for/IN
#   (NP some/DT unknown/JJ reason/NN)
#   )/)
#   ,/,
#   (NP the/DT base/NN)
#   8/128/CD
#   GB/NNP
#   (NP version/NN)
#   of/IN
#   the/DT
#   9/CD
#   Pro/NNP
#   is/VBZ
#   not/RB
#   available/JJ
#   ./.
#   This/DT
#   means/VBZ
#   you/PRP
#   can/MD
#   have/VB
#   (NP the/DT vanilla/NN)
#   (NP phone/NN)
#   for/IN
#   $/$
#   730/CD
#   or/CC
#   the/DT
#   12/256/CD
#   GB/NNP
#   Pro/NNP
#   for/IN
#   $/$
#   1,070/CD)

# %%
nltk.help.upenn_tagset()
# Out:
# $: dollar
#     $ -$ --$ A$ C$ HK$ M$ NZ$ S$ U.S.$ US$
# '': closing quotation mark
#     ' ''
# (: opening parenthesis
#     ( [ {
# ): closing parenthesis
#     ) ] }
# ,: comma
#     ,
# --: dash
#     --
# .: sentence terminator
#     . ! ?
# :: colon or ellipsis
#     : ; ...
# CC: conjunction, coordinating
#     & 'n and both but either et for less minus neither nor or plus so
#     therefore times v. versus vs. whether yet
# CD: numeral, cardinal
#     mid-1890 nine-thirty forty-two one-tenth ten million 0.5 one forty-
#     seven 1987 twenty '79 zero two 78-degrees eighty-four IX '60s .025
#     fifteen 271,124 dozen quintillion DM2,000 ...
# DT: determiner
#     all an another any both del each either every half la many much nary
#     neither no some such that the them these this those
# EX: existential there
#     there
# FW: foreign word
#     gemeinschaft hund ich jeux habeas Haementeria Herr K'ang-si vous
# ...

# %%
import nltk

# %%
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     f:\paraphrase\paraphraseenv\share\nltk_data...
# [nltk_data]   Unzipping corpora\wordnet.zip.
# True

# %%
import nltk
from nltk.corpus import wordnet   #Import wordnet from the NLTK

# %%
wordnet.synsets('ambidextrous')
# Out:
# [Synset('ambidextrous.a.01'), Synset('ambidextrous.s.02')]

# %%
syn = list()
for synset in wordnet.synsets("cheapest"):
    for lemma in synset.lemmas():
        syn.append(lemma.name())
print('Synonyms: ' + str(syn))
# Out:
# Synonyms: ['cheap', 'inexpensive', 'brassy', 'cheap', 'flash', 'flashy', 'garish', 'gaudy', 'gimcrack', 'loud', 'meretricious', 'tacky', 'tatty', 'tawdry', 'trashy', 'bum', 'cheap', 'cheesy', 'chintzy', 'crummy', 'punk', 'sleazy', 'tinny', 'cheap', 'chinchy', 'chintzy']

# %%
wordnet.synsets("cheapest")[-1].lemmas()[-1].name()
# Out:
# 'chintzy'

# %%
# Then, we're going to use the term "program" to find synsets like so:
syns = wordnet.synsets("program")

# %%
tmp = []
for syns in wordnet.synsets("update"):
    tmp.extend(syns.lemma_names())
tmp = list(set(tmp))

# %%
w1 = wordnet.synset("update.n.01")
for i in tmp:
    try:
        w2 = wordnet.synset(i+".n.01")
    except:
        w2 = wordnet.synset(i+".v.01")
    print(" ".join(i.split('_')))
    print(w1.wup_similarity(w2))
# Out:
# update
# 1.0

# %%
wordnet.synset('phone.n.01').lemma_names()
# Out:
# ['telephone', 'phone', 'telephone_set']

# %%
final = "The Android 11 update comes with version number 3.150 and requires a download of 1.5GB. It bumps up the Android security patch level on the Nokia 4.2 to March 2021 and brings new features to the smartphone, such as chat bubbles and one-time app permissions."
tokens = nltk.word_tokenize(final)
tag = nltk.pos_tag(tokens)
tags_only = [i[1] for i in tag]
name_only = [i[0] for i in tag]
selected = [i for i, x in enumerate(tags_only) if x == "NN" or x=="JJ"]
selected_name = [name_only[i] for i in selected]

# %%
selected_name
# Out:
# ['update',
#  'version',
#  'number',
#  'download',
#  'security',
#  'patch',
#  'level',
#  'new',
#  'smartphone',
#  'such',
#  'one-time',
#  'app']

# %%
import random

# %%
syn = []
for i in selected:
    try:
        syn.append(random.choice(dictionary.synonym(tokens[i])))
    except:
        syn.append(tokens[i])
        pass
# Out:
# smartphone has no Synonyms in the API
# app has no Synonyms in the API

# %%
syn
# Out:
# ['modify',
#  'approximation',
#  'prevalence',
#  'transfer',
#  'secureness',
#  'fret',
#  'moderation',
#  'unused',
#  'smartphone',
#  'much',
#  'temporary',
#  'app']

# %%
selected_name
# Out:
# ['update',
#  'version',
#  'number',
#  'download',
#  'security',
#  'patch',
#  'level',
#  'new',
#  'smartphone',
#  'such',
#  'one-time',
#  'app']

# %%
dictionary.synonym('app')
# Out:
# app has no Synonyms in the API

# %%
wordnet.synsets("update")[-4].lemma_names()
# Out:
# ['update']

# %%
from PyDictionary import PyDictionary
dictionary=PyDictionary()

# %%
dictionary1 = PyDictionary("1000th")

# %%
dictionary1.synonym("1000th")
# Out:
# ['thousandth', 'ordinal']

# %%
dictionary1.getSynonyms()
# Out:
# [{'1000th': ['thousandth', 'ordinal']}]

# %%
dictionary.synonym("1000th")
# Out:
# ['thousandth', 'ordinal']

# %%
list(wordnet.all_lemma_names())
# Out:
# ['.22-caliber',
#  '.22-calibre',
#  '.22_caliber',
#  '.22_calibre',
#  '.38-caliber',
#  '.38-calibre',
#  '.38_caliber',
#  '.38_calibre',
#  '.45-caliber',
#  '.45-calibre',
#  '.45_caliber',
#  '.45_calibre',
#  '0',
#  '1',
#  '10',
#  '10-membered',
#  '100',
#  '1000',
#  '1000th',
#  '100th',
#  '101',
#  '101st',
#  '105',
#  '105th',
#  '10th',
#  '11',
#  '110',
#  '110th',
#  '115',
#  '115th',
#  '11th',
#  '12',
#  '120',
#  '120th',
#  '125',
#  '125th',
#  '12th',
#  '13',
#  '130',
#  '130th',
#  '135',
#  '135th',
#  '13th',
#  '14',
#  '140',
#  '140th',
#  '145',
#  '145th',
#  '14th',
#  '15',
#  '150',
#  '150th',
#  '155',
#  '155th',
#  '15th',
#  '16',
#  '160',
#  '160th',
#  '165',
#  '165th',
#  '16th',
#  '17',
#  '170',
#  '170th',
#  '175',
#  '175th',
#  '17th',
#  '18',
#  '180',
#  '180th',
#  '18th',
#  '19',
#  '190',
#  '190th',
#  '19th',
#  '1st',
#  '2',
#  '2-dimensional',
#  '20',
#  '200',
#  '200th',
#  '20th',
#  '21',
#  '21st',
# ...
